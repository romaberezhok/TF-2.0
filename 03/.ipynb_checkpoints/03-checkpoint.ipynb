# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Load data

# %%
mnist = keras.datasets.fashion_mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
class_names = ['top', 'trouser', 'pullover','dress', 'sandal', 'coat', 'shirt', 'sneaker', 'bag', 'ankle boot']

# %% [markdown]
# ### Data exploration

# %%
plt.figure()
plt.imshow(X_train[0], cmap='gray')
plt.colorbar()

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ### Build the model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model compilation
# - Loss Function
# - Optimizer
# - Metrics

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=10, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 9s 194us/sample - loss: 0.4969 - accuracy: 0.8210 - val_loss: 0.4135 - val_accuracy: 0.8508
# Epoch 2/10
# 48000/48000 [==============================] - 9s 188us/sample - loss: 0.3753 - accuracy: 0.8630 - val_loss: 0.3803 - val_accuracy: 0.8648
# Epoch 3/10
# 48000/48000 [==============================] - 9s 189us/sample - loss: 0.3370 - accuracy: 0.8760 - val_loss: 0.3588 - val_accuracy: 0.8673
# Epoch 4/10
# 48000/48000 [==============================] - 9s 189us/sample - loss: 0.3143 - accuracy: 0.8833 - val_loss: 0.3505 - val_accuracy: 0.8792
# Epoch 5/10
# 48000/48000 [==============================] - 9s 189us/sample - loss: 0.2958 - accuracy: 0.8892 - val_loss: 0.3347 - val_accuracy: 0.8813
# Epoch 6/10
# 48000/48000 [==============================] - 9s 190us/sample - loss: 0.2805 - accuracy: 0.8954 - val_loss: 0.3239 - val_accuracy: 0.8825
# Epoch 7/10
# 48000/48000 [==============================] - 9s 189us/sample - loss: 0.2711 - accuracy: 0.8982 - val_loss: 0.3521 - val_accuracy: 0.8767
# Epoch 8/10
# 48000/48000 [==============================] - 9s 190us/sample - loss: 0.2597 - accuracy: 0.9021 - val_loss: 0.3418 - val_accuracy: 0.8817
# Epoch 9/10
# 48000/48000 [==============================] - 9s 191us/sample - loss: 0.2495 - accuracy: 0.9060 - val_loss: 0.3480 - val_accuracy: 0.8753
# Epoch 10/10
# 48000/48000 [==============================] - 9s 193us/sample - loss: 0.2422 - accuracy: 0.9089 - val_loss: 0.3307 - val_accuracy: 0.8865

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(test_acc)
# Out:
# 10000/10000 [==============================] - 0s 33us/sample - loss: 0.3688 - accuracy: 0.8749
# 0.8749

# %%
y_pred = model.predict_classes(X_test)

# %%
history.history
# Out:
# {'loss': [0.4968964294270457,
#   0.37534029740064095,
#   0.3370038707723385,
#   0.3143096879437629,
#   0.2957824643773226,
#   0.28050536132732,
#   0.271054002175581,
#   0.2596564120972774,
#   0.24952154275510413,
#   0.2421835061169501],
#  'accuracy': [0.8209583,
#   0.86302084,
#   0.8759792,
#   0.8833333,
#   0.8891875,
#   0.8954375,
#   0.89825,
#   0.90208334,
#   0.9060208,
#   0.9089375],
#  'val_loss': [0.41354371249287697,
#   0.38028306203554774,
#   0.3588230128198241,
#   0.3505096176745913,
#   0.33471441578886396,
#   0.3239212218070558,
#   0.3521485117190362,
#   0.34179879728782303,
#   0.3479991880055362,
#   0.330710406694343],
#  'val_accuracy': [0.85083336,
#   0.86483335,
#   0.86725,
#   0.87925,
#   0.88133335,
#   0.8825,
#   0.87675,
#   0.88166666,
#   0.8753333,
#   0.8865]}

# %%
# Plot training and validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# Plot training and validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %% [markdown]
# ### Plot confusion matrix

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
mat = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(mat, figsize=(10,10), show_normed=True)
# Out:
# (<Figure size 720x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb62cb9a690>)
